# %%
import kagglehub

path = kagglehub.dataset_download("parisrohan/credit-score-classification")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/parisrohan/credit-score-classification?dataset_version_number=1...
# 100%|██████████| 9.51M/9.51M [00:01<00:00, 8.49MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/parisrohan/credit-score-classification/versions/1

# %%
# !unzip ./data.zip
# Out:
# Archive:  ./data.zip
# replace data/test.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("./data/train.csv")
df.head()
# Out:
# C:\Users\bkh15\AppData\Local\Temp\ipykernel_23060\1721515521.py:7: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./data/train.csv")
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
#    Outstanding_Debt Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                26.822620  22 Years and 1 Months
# 1            809.98                31.944960                    NaN
# 2            809.98                28.609352  22 Years and 3 Months
# 3            809.98                31.377862  22 Years and 4 Months
# 4            809.98                24.797347  22 Years and 5 Months
#
#    Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
# 0                     No           49.574949       80.41529543900253
# 1                     No           49.574949      118.28022162236736
# 2                     No           49.574949         81.699521264648
# 3                     No           49.574949       199.4580743910713
# 4                     No           49.574949      41.420153086217326
#
#                   Payment_Behaviour     Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments  312.49408867943663         Good
# 1    Low_spent_Large_value_payments  284.62916249607184         Good
# 2   Low_spent_Medium_value_payments   331.2098628537912         Good
# 3    Low_spent_Small_value_payments  223.45130972736786         Good
# 4  High_spent_Medium_value_payments  341.48923103222177         Good
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning

# %%
def remove_underscore(df, col):
    df[col] = df[col].apply(lambda x: str(x).replace("_", "") if str(x) else x)
    df[col] = pd.to_numeric(df[col], errors="coerce")

# %%
remove_underscore(df, "Age")
remove_underscore(df, "Annual_Income")
remove_underscore(df, "Outstanding_Debt")
remove_underscore(df, "Monthly_Balance")
remove_underscore(df, "Num_of_Loan")
remove_underscore(df, "Num_of_Delayed_Payment")
remove_underscore(df, "Amount_invested_monthly")
remove_underscore(df, "Credit_Mix")
remove_underscore(df, "Changed_Credit_Limit")

df['Payment_of_Min_Amount'] = df['Payment_of_Min_Amount'].str.strip().str.lower()
df['Payment_of_Min_Amount'] = df['Payment_of_Min_Amount'].map({'yes': 1, 'no': 0})
df["Credit_Score"] = df["Credit_Score"].map({"Good":2, "Poor":0, "Standard":1})

def convert_to_year_fraction(credit_history_age):
    if pd.isnull(credit_history_age):
        return np.nan
    match = re.match(r"(\d+)\s+Years?\s+and\s+(\d+)\s+Months?", credit_history_age)
    if match:
        years = int(match.group(1))
        months = int(match.group(2))
        return years + months / 12
    return np.nan

df['Credit_History_Age_in_Years'] = df['Credit_History_Age'].apply(convert_to_year_fraction)
df.head()
# Out:
#        ID Customer_ID     Month           Name  Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh   23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh   23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh   23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh   23  821-00-0265  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0       19114.12            1824.843333                  3  ...
# 1       19114.12                    NaN                  3  ...
# 2       19114.12                    NaN                  3  ...
# 3       19114.12                    NaN                  3  ...
# 4       19114.12            1824.843333                  3  ...
#
#    Outstanding_Debt  Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                 26.822620  22 Years and 1 Months
# 1            809.98                 31.944960                    NaN
# 2            809.98                 28.609352  22 Years and 3 Months
# 3            809.98                 31.377862  22 Years and 4 Months
# 4            809.98                 24.797347  22 Years and 5 Months
#
#   Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                   0.0            49.574949                80.415295
# 1                   0.0            49.574949               118.280222
# 2                   0.0            49.574949                81.699521
# 3                   0.0            49.574949               199.458074
# 4                   0.0            49.574949                41.420153
#
#                   Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 0   High_spent_Small_value_payments       312.494089             2
# 1    Low_spent_Large_value_payments       284.629162             2
# 2   Low_spent_Medium_value_payments       331.209863             2
# 3    Low_spent_Small_value_payments       223.451310             2
# 4  High_spent_Medium_value_payments       341.489231             2
#
#    Credit_History_Age_in_Years
# 0                    22.083333
# 1                          NaN
# 2                    22.250000
# 3                    22.333333
# 4                    22.416667
#
# [5 rows x 29 columns]

# %%
df.describe()
# Out:
#                  Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  100000.000000   1.000000e+05           84998.000000      100000.000000
# mean      110.649700   1.764157e+05            4194.170850          17.091280
# std       686.244717   1.429618e+06            3183.686167         117.404834
# min      -500.000000   7.005930e+03             303.645417          -1.000000
# 25%        24.000000   1.945750e+04            1625.568229           3.000000
# 50%        33.000000   3.757861e+04            3093.745000           6.000000
# 75%        42.000000   7.279092e+04            5957.448333           7.000000
# max      8698.000000   2.419806e+07           15204.633333        1798.000000
#
#        Num_Credit_Card  Interest_Rate    Num_of_Loan  Delay_from_due_date  \
# count     100000.00000  100000.000000  100000.000000        100000.000000
# mean          22.47443      72.466040       3.009960            21.068780
# std          129.05741     466.422621      62.647879            14.860104
# min            0.00000       1.000000    -100.000000            -5.000000
# 25%            4.00000       8.000000       1.000000            10.000000
# 50%            5.00000      13.000000       3.000000            18.000000
# 75%            7.00000      20.000000       5.000000            28.000000
# max         1499.00000    5797.000000    1496.000000            67.000000
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# count            92998.000000          97909.000000          98035.000000
# mean                30.923342             10.389025             27.754251
# std                226.031892              6.789496            193.177339
# min                 -3.000000             -6.490000              0.000000
# 25%                  9.000000              5.320000              3.000000
# 50%                 14.000000              9.400000              6.000000
# 75%                 18.000000             14.870000              9.000000
# max               4397.000000             36.970000           2597.000000
#
#        Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# count         0.0     100000.000000             100000.000000
# mean          NaN       1426.220376                 32.285173
# std           NaN       1155.129026                  5.116875
# min           NaN          0.230000                 20.000000
# 25%           NaN        566.072500                 28.052567
# 50%           NaN       1166.155000                 32.305784
# 75%           NaN       1945.962500                 36.496663
# max           NaN       4998.070000                 50.000000
#
#        Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# count           87993.000000        100000.000000             95521.000000
# mean                0.594661          1403.118217               637.412998
# std                 0.490960          8306.041270              2043.319327
# min                 0.000000             0.000000                 0.000000
# 25%                 0.000000            30.306660                74.534002
# 50%                 1.000000            69.249473               135.925682
# 75%                 1.000000           161.224249               265.731733
# max                 1.000000         82331.000000             10000.000000
#
#        Monthly_Balance  Credit_Score  Credit_History_Age_in_Years
# count     9.880000e+04  100000.00000                 90970.000000
# mean     -3.036437e+22       0.88830                    18.432950
# std       3.181295e+24       0.67512                     8.311780
# min      -3.333333e+26       0.00000                     0.083333
# 25%       2.700922e+02       0.00000                    12.000000
# 50%       3.367192e+02       1.00000                    18.250000
# 75%       4.702202e+02       1.00000                    25.166667
# max       1.602041e+03       2.00000                    33.666667

# %%
n = 5

for column in df.columns:
    if pd.api.types.is_numeric_dtype(df[column]):
        print(f"Top {n} rows with the highest values in column '{column}':")
        display(df.nlargest(n, column))
        print("\n")
# Out:
# Top 5 rows with the highest values in column 'Age':
#             ID Customer_ID   Month             Name   Age          SSN  \
# 71732  0x1ba4e  CUS_0x3909     May    Karen Jacobsk  8698  833-13-6967
# 82739  0x1facd  CUS_0x5984   April        Jim Wolfk  8697  401-11-2941
# 35557   0xe657  CUS_0x4f3e    June        Beckfordz  8682  341-94-5301
# 82335  0x1f86d   CUS_0x997  August              enw  8678  914-87-9289
# 13372   0x645a  CUS_0x5deb     May  SaPinto" Tommyl  8674  091-76-5591
#
#          Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 71732  Entrepreneur       17423.69            1707.974167                  6
# 82739      Engineer       59992.12            5265.343333                  6
# 35557      Mechanic       17766.93            1219.577500                  5
# 82335      Mechanic       23681.87            1826.489167                  3
# 13372        Doctor       59681.56            5229.463333                  6
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio     Credit_History_Age  \
# 71732  ...           1158.96                 34.351207  31 Years and 6 Months
# 82739  ...           2600.85                 31.899961   6 Years and 5 Months
# 35557  ...            195.48                 40.778226  30 Years and 7 Months
# 82335  ...           1433.17                 31.882977  21 Years and 0 Months
# 13372  ...             55.92                 25.418201                    NaN
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 71732                   1.0             0.000000               132.024626
# 82739                   1.0           349.330723               240.960356
# 35557                   0.0             9.712736                57.169214
# 82335                   0.0            41.642793                48.424448
# 13372                   0.0         58054.000000               432.654775
#
#                      Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 71732   Low_spent_Large_value_payments       308.772790             1
# 82739                           !@9#%8       206.243254             0
# 35557   Low_spent_Small_value_payments       345.075800             1
# 82335  High_spent_Small_value_payments       352.581675             1
# 13372   Low_spent_Large_value_payments       244.046377             1
#
#        Credit_History_Age_in_Years
# 71732                    31.500000
# 82739                     6.416667
# 35557                    30.583333
# 82335                    21.000000
# 13372                          NaN
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Annual_Income':
#             ID Customer_ID  Month               Name  Age          SSN  \
# 48302  0x13104   CUS_0xcfc   July  Catherine Bosleyz   31  555-99-1654
# 7814    0x43c8  CUS_0xb1a0   July                NaN   17  249-90-4145
# 59059  0x1700d  CUS_0x5b6f  April          Forgionej   21  054-49-7239
# 14588   0x6b7a  CUS_0x6cad    May              Mattl   38    #F%$D@*&8
# 27262   0xb5bc  CUS_0x1a23   July       Paige Gancec   51  092-81-2077
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 48302   Engineer     24198062.0            1135.525417                  4
# 7814      Lawyer     24188807.0            1067.655833                  8
# 59059   Mechanic     24177153.0            2373.828333                  4
# 14588    Teacher     24160009.0            3852.982500                 10
# 27262     Lawyer     24105369.0            3165.787500                  3
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio  \
# 48302  ...            672.49                 34.790192
# 7814   ...           3703.96                 41.268945
# 59059  ...           1443.42                 39.408584
# 14588  ...           3148.34                 25.225734
# 27262  ...            671.94                 29.621716
#
#            Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 48302   18 Years and 4 Months                   0.0            46.388945
# 7814    10 Years and 1 Months                   NaN            87.323423
# 59059   21 Years and 2 Months                   0.0             0.000000
# 14588  12 Years and 11 Months                   1.0           196.888046
# 27262   31 Years and 4 Months                   0.0            57.514937
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 48302                53.573863    Low_spent_Large_value_payments
# 7814                 25.385696   High_spent_Small_value_payments
# 59059               136.175542   Low_spent_Medium_value_payments
# 14588               159.593972  High_spent_Medium_value_payments
# 27262               237.622977   Low_spent_Medium_value_payments
#
#        Monthly_Balance  Credit_Score  Credit_History_Age_in_Years
# 48302       283.589734             2                    18.333333
# 7814        254.056464             1                    10.083333
# 59059       381.207291             1                    21.166667
# 14588       278.816232             1                    12.916667
# 27262       301.440837             1                    31.333333
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Monthly_Inhand_Salary':
#             ID Customer_ID     Month           Name  Age          SSN  \
# 62728  0x1858e   CUS_0xbcf   January  Lisa Lambertm   44  420-94-4649
# 62729  0x1858f   CUS_0xbcf  February  Lisa Lambertm   44  420-94-4649
# 62730  0x18590   CUS_0xbcf     March  Lisa Lambertm   44    #F%$D@*&8
# 62731  0x18591   CUS_0xbcf     April  Lisa Lambertm   44  420-94-4649
# 62732  0x18592   CUS_0xbcf       May  Lisa Lambertm   44  420-94-4649
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 62728     Lawyer       179239.6           15204.633333                  5
# 62729     Lawyer       179239.6           15204.633333                  5
# 62730     Lawyer       179239.6           15204.633333                  5
# 62731     Lawyer       179239.6           15204.633333                  5
# 62732     Lawyer       179239.6           15204.633333                  5
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio     Credit_History_Age  \
# 62728  ...           1246.12                 38.640882  18 Years and 4 Months
# 62729  ...           1246.12                 41.838981  18 Years and 5 Months
# 62730  ...           1246.12                 28.981811  18 Years and 6 Months
# 62731  ...           1246.12                 46.840987                    NaN
# 62732  ...           1246.12                 28.487553  18 Years and 8 Months
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 62728                   0.0           208.797378               100.848772
# 62729                   0.0           208.797378               297.295373
# 62730                   0.0           208.797378              1961.218850
# 62731                   0.0           208.797378               213.242371
# 62732                   0.0           208.797378               658.710760
#
#                      Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 62728  High_spent_Large_value_payments      1450.817184             2
# 62729  High_spent_Small_value_payments      1274.370582             2
# 62730   Low_spent_Small_value_payments              NaN             2
# 62731  High_spent_Large_value_payments      1338.423585             1
# 62732  High_spent_Small_value_payments       912.955195             1
#
#        Credit_History_Age_in_Years
# 62728                    18.333333
# 62729                    18.416667
# 62730                    18.500000
# 62731                          NaN
# 62732                    18.666667
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Num_Bank_Accounts':
#             ID Customer_ID     Month              Name  Age          SSN  \
# 20277   0x8ccf  CUS_0x7fd9      June      en Deightono   55  165-28-2986
# 64537  0x19027  CUS_0x11c1  February  Mark Felsenthalk   34  688-99-5258
# 29242   0xc158  CUS_0x36a0     March              Jedh   51  881-20-6457
# 69059  0x1aaa5  CUS_0x9a7a     April             Nickn   39  352-84-7006
# 35195   0xe439  CUS_0x3c3a     April             Alexh   37  014-29-7065
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 20277     Accountant      32946.220                    NaN               1798
# 64537       Engineer      29902.220            2230.851667               1798
# 29242  Media_Manager      35976.970            3126.080833               1794
# 69059         Writer      81438.560            6989.546667               1794
# 35195      Developer       8499.645             817.303750               1793
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio     Credit_History_Age  \
# 20277  ...           1330.02                 21.743562  18 Years and 0 Months
# 64537  ...            533.71                 34.380248  19 Years and 9 Months
# 29242  ...            568.67                 34.730228  31 Years and 4 Months
# 69059  ...            509.44                 34.745910   7 Years and 6 Months
# 35195  ...           2573.10                 34.367790  15 Years and 8 Months
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 20277                   0.0            46.244585               264.366596
# 64537                   1.0            66.210327               282.839777
# 29242                   0.0            53.686329               110.355050
# 69059                   1.0            84.273956               195.466316
# 35195                   NaN            34.700690                33.569204
#
#                       Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 20277    Low_spent_Large_value_payments       245.940653             1
# 64537    Low_spent_Small_value_payments       164.035063             1
# 29242  High_spent_Medium_value_payments       398.566704             2
# 69059  High_spent_Medium_value_payments       669.214395             1
# 35195    Low_spent_Large_value_payments       283.460481             0
#
#        Credit_History_Age_in_Years
# 20277                    18.000000
# 64537                    19.750000
# 29242                    31.333333
# 69059                     7.500000
# 35195                    15.666667
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Num_Credit_Card':
#             ID Customer_ID   Month            Name  Age          SSN  \
# 25015   0xa891  CUS_0x1fdc  August    Angela Moona   29  896-78-0268
# 72123  0x1bc99  CUS_0xb987   April   Jessica Wohlz   16  738-03-2141
# 18343   0x8179  CUS_0x5bdb  August              Rv   42  419-12-7067
# 62075  0x181b9  CUS_0x9448   April  Ryan Schladers   41  369-50-5456
# 77711  0x1dd55  CUS_0x25c4  August      Zieminskia   40  967-73-5542
#
#        Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 25015  Accountant      14189.300             973.441667                  8
# 72123   Scientist      10186.535             552.877917                  8
# 18343    Engineer       7866.910             814.575833                  3
# 62075     _______      79090.740            6676.895000                  2
# 77711  Accountant      14717.280            1069.440000                  5
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio     Credit_History_Age  \
# 25015  ...           1281.77                 34.227196  18 Years and 9 Months
# 72123  ...           2484.47                 27.794426  15 Years and 4 Months
# 18343  ...           1076.09                 37.383784  11 Years and 6 Months
# 62075  ...            753.00                 33.061205                    NaN
# 77711  ...            148.52                 29.772539  21 Years and 6 Months
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 25015                   NaN            19.792811                90.692474
# 72123                   1.0            28.824949                37.623726
# 18343                   1.0            23.926064             10000.000000
# 62075                   0.0           155.441868               668.314856
# 77711                   0.0            31.083719                43.742084
#
#                      Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 25015   Low_spent_Small_value_payments       276.858882             0
# 72123   Low_spent_Small_value_payments       278.839117             0
# 18343                           !@9#%8       311.938233             1
# 62075  Low_spent_Medium_value_payments       123.932777             2
# 77711   Low_spent_Small_value_payments       322.118197             2
#
#        Credit_History_Age_in_Years
# 25015                    18.750000
# 72123                    15.333333
# 18343                    11.500000
# 62075                          NaN
# 77711                    21.500000
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Interest_Rate':
#             ID Customer_ID     Month              Name  Age          SSN  \
# 71641  0x1b9c7  CUS_0x3fd9  February            Jussih   49  856-12-9184
# 73583  0x1c525  CUS_0x8b85    August          Jessicak   47  927-54-7427
# 23512   0x9fc6  CUS_0x2fab   January  Anna Yukhananovd   26  411-00-6543
# 88505  0x21c97  CUS_0x19a8  February               NaN   42  738-50-7769
# 77710  0x1dd54  CUS_0x25c4      July        Zieminskia   40  967-73-5542
#
#          Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 71641      Engineer       76325.67            6644.472500                  5
# 73583  Entrepreneur       56615.10            4908.925000                  5
# 23512       Manager       75804.94            6120.078333                  0
# 88505      Musician       30683.42            2397.951667                  4
# 77710    Accountant       14717.28            1069.440000                  5
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio     Credit_History_Age  \
# 71641  ...           1392.95                 38.653956  23 Years and 2 Months
# 73583  ...           1170.66                 37.193618  20 Years and 2 Months
# 23512  ...            330.82                 35.641926  31 Years and 9 Months
# 88505  ...              7.24                 29.706823                    NaN
# 77710  ...            148.52                 28.221988  21 Years and 5 Months
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 71641                   1.0           148.616044               187.252236
# 73583                   0.0            45.618895               135.917012
# 23512                   0.0           141.289448                51.867242
# 88505                   0.0            46.884456                64.523403
# 77710                   0.0         58962.000000                17.478496
#
#                       Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 71641   High_spent_Small_value_payments       588.578970             1
# 73583   High_spent_Small_value_payments       569.356593             1
# 23512   High_spent_Large_value_payments       658.851143             2
# 88505  High_spent_Medium_value_payments       378.387307             1
# 77710   High_spent_Large_value_payments       298.381784             1
#
#        Credit_History_Age_in_Years
# 71641                    23.166667
# 73583                    20.166667
# 23512                    31.750000
# 88505                          NaN
# 77710                    21.416667
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Num_of_Loan':
#             ID Customer_ID    Month            Name  Age          SSN  \
# 74808  0x1cc56  CUS_0x15a7  January        Philippy   21  755-77-1230
# 30391   0xc811  CUS_0x90cf   August         McCoolw   53  058-50-1241
# 3059    0x27ed  CUS_0xaf23    April   Nick Edwardsg   37  231-01-3965
# 28428   0xbc92  CUS_0x272a      May      Katharinax   25  444-95-6664
# 58597  0x16d57  CUS_0x3941     June  Mirna Sleimane   17  782-05-3224
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 74808       Mechanic      120368.32           10210.693333                  1
# 30391  Media_Manager      106234.11            8699.842500                  4
# 3059         _______       17164.72            1223.393333                 10
# 28428        Teacher       29633.99            2370.499167                  7
# 58597     Accountant       59993.32            4957.443333                  5
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio     Credit_History_Age  \
# 74808  ...            785.01                 26.196732                    NaN
# 30391  ...            939.40                 36.009422                    NaN
# 3059   ...           4813.02                 29.959176  10 Years and 8 Months
# 28428  ...            113.42                 36.076178   6 Years and 2 Months
# 58597  ...           1326.50                 31.146913   9 Years and 8 Months
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 74808                   0.0           288.949692               228.021229
# 30391                   0.0           201.113490               625.847156
# 3059                    1.0            99.126378                63.569916
# 28428                   NaN            32.226013                89.058968
# 58597                   1.0           205.989320                57.656451
#
#                      Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 74808  High_spent_Large_value_payments       744.098412             1
# 30391   Low_spent_Large_value_payments       313.023604             1
# 3059    Low_spent_Large_value_payments       229.643039             0
# 28428  High_spent_Small_value_payments       375.764936             1
# 58597  High_spent_Large_value_payments       472.098563             1
#
#        Credit_History_Age_in_Years
# 74808                          NaN
# 30391                          NaN
# 3059                     10.666667
# 28428                     6.166667
# 58597                     9.666667
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Delay_from_due_date':
#            ID Customer_ID     Month     Name  Age          SSN  Occupation  \
# 477    0x18cb  CUS_0x8f17      June   Ermans   46  794-17-4490     _______
# 13913  0x6787   CUS_0x7df  February  Juliend   26  556-57-5003  Accountant
# 13919  0x678d   CUS_0x7df    August  Juliend   26  556-57-5003  Accountant
# 18945  0x8503  CUS_0x7e3e  February      NaN   30  230-16-9822    Engineer
# 22648  0x9ab6  CUS_0x910a   January   Lynchp   16  924-42-4638    Mechanic
#
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 477         41746.76            3651.896667                  8  ...
# 13913       14406.71            1236.559167                973  ...
# 13919       14406.71            1236.559167                  6  ...
# 18945       80932.92            6759.410000                  8  ...
# 22648       16701.54            1555.795000                  7  ...
#
#        Outstanding_Debt  Credit_Utilization_Ratio      Credit_History_Age  \
# 477             1936.79                 32.159610   19 Years and 6 Months
# 13913           1286.90                 27.285234                     NaN
# 13919           1286.90                 34.860396   17 Years and 6 Months
# 18945           2696.09                 42.047788  15 Years and 10 Months
# 22648           3356.86                 26.584542    3 Years and 5 Months
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 477                     1.0           102.283398               199.127606
# 13913                   1.0            53.550032               159.603762
# 13919                   1.0            53.550032               119.528636
# 18945                   1.0           192.810878               101.123272
# 22648                   1.0            45.012674               141.718752
#
#                      Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 477    High_spent_Small_value_payments       323.778663             0
# 13913   Low_spent_Small_value_payments       200.502123             1
# 13919   Low_spent_Small_value_payments       240.577249             0
# 18945  High_spent_Large_value_payments       622.006850             0
# 22648  Low_spent_Medium_value_payments       248.848074             1
#
#        Credit_History_Age_in_Years
# 477                      19.500000
# 13913                          NaN
# 13919                    17.500000
# 18945                    15.833333
# 22648                     3.416667
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Num_of_Delayed_Payment':
#             ID Customer_ID    Month         Name  Age          SSN  \
# 51565  0x14423  CUS_0x8f59     June     Jessicad   36  705-77-2792
# 82232  0x1f7d6  CUS_0xbc0c  January      Rascoey   50  157-90-1957
# 31796   0xd04e  CUS_0x8636      May      Alexeiy   33  644-42-8469
# 63043  0x18765  CUS_0x3a06    April        Janes   32  079-88-9608
# 95038  0x242dc  CUS_0xb6e0     July  Aditi Shahb   24  318-50-9417
#
#        Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 51565    Mechanic       24577.48            2055.123333                  5
# 82232   Scientist       32637.88            2514.823333                  5
# 31796    Mechanic      101342.20            8444.183333                  2
# 63043  Journalist       30560.73            2692.727500                  5
# 95038     Manager      157794.60           13225.550000                  3
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio  \
# 51565  ...            844.54                 37.564481
# 82232  ...           1061.77                 35.623966
# 31796  ...            828.02                 40.074788
# 63043  ...           1354.32                 33.602418
# 95038  ...           1198.78                 38.190160
#
#            Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 51565   14 Years and 7 Months                   1.0            95.538487
# 82232   17 Years and 3 Months                   1.0            69.574057
# 31796    7 Years and 2 Months                   1.0           114.329989
# 63043  24 Years and 10 Months                   0.0            73.513154
# 95038   27 Years and 4 Months                   0.0           261.873309
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 51565               105.950033    Low_spent_Small_value_payments
# 82232                27.566888  High_spent_Medium_value_payments
# 31796               446.169384    Low_spent_Large_value_payments
# 63043               258.542228    Low_spent_Small_value_payments
# 95038              1319.227586   Low_spent_Medium_value_payments
#
#        Monthly_Balance  Credit_Score  Credit_History_Age_in_Years
# 51565       294.023813             1                    14.583333
# 82232       404.341388             1                    17.250000
# 31796       553.918960             1                     7.166667
# 63043       227.217368             2                    24.833333
# 95038        21.454105             1                    27.333333
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Changed_Credit_Limit':
#             ID Customer_ID     Month             Name  Age          SSN  \
# 21807   0x95c5  CUS_0x64a4    August     Oliver Hirtj   46  907-98-0707
# 45056  0x11e02  CUS_0xb017   January      Yukhananovn   42  542-27-9387
# 36433   0xeb7b  CUS_0xc702  February  Renee Maltezoua   28  559-27-4003
# 82009  0x1f687  CUS_0x744f  February          Maashov   26  528-53-4876
# 62677  0x1853f  CUS_0xa610      June    Strupczewskid   38  548-77-4930
#
#        Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 21807   Developer       35372.36            2865.696667                  8
# 45056     _______       15766.76            1288.896667                  8
# 36433     Manager       31959.40            2472.283333                  8
# 82009      Doctor        9527.09             604.924167                  8
# 62677  Accountant       62616.99                    NaN                  7
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio     Credit_History_Age  \
# 21807  ...           3850.97                 34.483402   7 Years and 8 Months
# 45056  ...           3479.89                 29.722702                    NaN
# 36433  ...           2753.45                 38.561521  5 Years and 10 Months
# 82009  ...           4208.66                 27.889116  14 Years and 0 Months
# 62677  ...           4420.25                 39.108421   3 Years and 3 Months
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 21807                   1.0           173.241966                77.477504
# 45056                   NaN            76.953045               111.137948
# 36433                   1.0           201.319053                79.984039
# 82009                   1.0            61.729526                35.357573
# 62677                   1.0           322.548211               152.403036
#
#                       Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 21807  High_spent_Medium_value_payments       285.850197             1
# 45056    Low_spent_Small_value_payments       230.798674             1
# 36433  High_spent_Medium_value_payments       215.925242             1
# 82009   Low_spent_Medium_value_payments       243.405318             1
# 62677  High_spent_Medium_value_payments       302.157003             1
#
#        Credit_History_Age_in_Years
# 21807                     7.666667
# 45056                          NaN
# 36433                     5.833333
# 82009                    14.000000
# 62677                     3.250000
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Num_Credit_Inquiries':
#             ID Customer_ID    Month             Name  Age          SSN  \
# 37718   0xf300  CUS_0x9b8b     July  Karen Freifeldr   37  963-35-0135
# 19525   0x8867  CUS_0x41f0     June            Katen   18  803-57-7987
# 4880    0x329a  CUS_0x84da  January    Tara LaCapraa   54    #F%$D@*&8
# 57989  0x169c7  CUS_0x554b     June          Alexeih   53  776-27-8471
# 52054  0x14700  CUS_0x87c5     July  Jonathan Cableo   40  362-65-9938
#
#          Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 37718    Journalist        8940.14             933.011667                  3
# 19525       Teacher       18507.00            1561.250000                  6
# 4880         Doctor      130688.56           11134.713333                  0
# 57989  Entrepreneur       15127.05            1482.339210                  8
# 52054        Doctor      120174.40           10016.533333                  7
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio     Credit_History_Age  \
# 37718  ...           1250.27                 27.465214                    NaN
# 19525  ...           1814.83                 33.192739  10 Years and 1 Months
# 4880   ...            466.13                 27.269504  15 Years and 8 Months
# 57989  ...            194.30                 32.624698  26 Years and 1 Months
# 52054  ...            828.59                 30.582894  18 Years and 1 Months
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 37718                   1.0            35.221703                20.945038
# 19525                   1.0            34.039146                50.109781
# 4880                    NaN             0.000000               663.033973
# 57989                   0.0            93.510337                76.233564
# 52054                   1.0            94.898454               660.802838
#
#                       Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 37718  High_spent_Medium_value_payments       287.134426             1
# 19525   Low_spent_Medium_value_payments       351.976073             1
# 4880    Low_spent_Medium_value_payments       730.437360             2
# 57989   Low_spent_Medium_value_payments       324.763139             1
# 52054    Low_spent_Small_value_payments       535.952041             1
#
#        Credit_History_Age_in_Years
# 37718                          NaN
# 19525                    10.083333
# 4880                     15.666667
# 57989                    26.083333
# 52054                    18.083333
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Credit_Mix':
#        ID Customer_ID     Month           Name  Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh   23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh   23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh   23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh   23  821-00-0265  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0       19114.12            1824.843333                  3  ...
# 1       19114.12                    NaN                  3  ...
# 2       19114.12                    NaN                  3  ...
# 3       19114.12                    NaN                  3  ...
# 4       19114.12            1824.843333                  3  ...
#
#    Outstanding_Debt  Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                 26.822620  22 Years and 1 Months
# 1            809.98                 31.944960                    NaN
# 2            809.98                 28.609352  22 Years and 3 Months
# 3            809.98                 31.377862  22 Years and 4 Months
# 4            809.98                 24.797347  22 Years and 5 Months
#
#   Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                   0.0            49.574949                80.415295
# 1                   0.0            49.574949               118.280222
# 2                   0.0            49.574949                81.699521
# 3                   0.0            49.574949               199.458074
# 4                   0.0            49.574949                41.420153
#
#                   Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 0   High_spent_Small_value_payments       312.494089             2
# 1    Low_spent_Large_value_payments       284.629162             2
# 2   Low_spent_Medium_value_payments       331.209863             2
# 3    Low_spent_Small_value_payments       223.451310             2
# 4  High_spent_Medium_value_payments       341.489231             2
#
#    Credit_History_Age_in_Years
# 0                    22.083333
# 1                          NaN
# 2                    22.250000
# 3                    22.333333
# 4                    22.416667
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Outstanding_Debt':
#           ID Customer_ID     Month           Name  Age          SSN  \
# 8736  0x4932  CUS_0xc5ee   January  Chris Petersw   23    #F%$D@*&8
# 8737  0x4933  CUS_0xc5ee  February            NaN   24  534-84-1363
# 8738  0x4934  CUS_0xc5ee     March  Chris Petersw   24  534-84-1363
# 8739  0x4935  CUS_0xc5ee     April  Chris Petersw   24    #F%$D@*&8
# 8740  0x4936  CUS_0xc5ee       May  Chris Petersw   24  534-84-1363
#
#      Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 8736   Mechanic       50043.27            4132.272500                  7  ...
# 8737   Mechanic       50043.27            4132.272500                  7  ...
# 8738   Mechanic       50043.27            4132.272500                  7  ...
# 8739   Mechanic       50043.27                    NaN                  7  ...
# 8740    _______       50043.27            3797.351204                  7  ...
#
#       Outstanding_Debt  Credit_Utilization_Ratio    Credit_History_Age  \
# 8736           4998.07                 38.247029  6 Years and 4 Months
# 8737           4998.07                 35.968020  6 Years and 5 Months
# 8738           4998.07                 30.737818  6 Years and 6 Months
# 8739           4998.07                 35.833785                   NaN
# 8740           4998.07                 26.543491                   NaN
#
#      Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 8736                   1.0           184.879182             10000.000000
# 8737                   1.0           184.879182                69.799383
# 8738                   1.0           184.879182                80.925275
# 8739                   1.0           184.879182               112.950269
# 8740                   1.0           519.800477                47.031992
#
#                      Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 8736  High_spent_Medium_value_payments       388.473303             1
# 8737                            !@9#%8       398.548685             1
# 8738   High_spent_Small_value_payments       407.422793             1
# 8739  High_spent_Medium_value_payments       365.397799             2
# 8740  High_spent_Medium_value_payments       431.316076             2
#
#       Credit_History_Age_in_Years
# 8736                     6.333333
# 8737                     6.416667
# 8738                     6.500000
# 8739                          NaN
# 8740                          NaN
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Credit_Utilization_Ratio':
#             ID Customer_ID    Month           Name  Age          SSN  \
# 9382    0x4cf8  CUS_0x3655     July            NaN   30  512-00-8324
# 68000  0x1a472  CUS_0x751c  January       Jessican   19  220-63-1416
# 17029   0x79c7  CUS_0x9f7a     June   Dave Clarkes   55  692-62-0934
# 62954  0x186e0  CUS_0xa99a    March         Luciad   55  670-51-6382
# 87595  0x21741  CUS_0x1bde    April  en Hirschlere   36  027-51-8010
#
#        Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 9382       Lawyer      177907.72           13078.430052                  0
# 68000  Accountant      177696.92           15090.076667                  5
# 17029      Writer      178793.92           14642.493333                  1
# 62954     Teacher      177846.68           14855.556667                210
# 87595     Manager      170730.60           14353.550000                594
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio  \
# 9382   ...            685.01                 50.000000
# 68000  ...           1182.91                 49.564519
# 17029  ...           1015.37                 49.522324
# 62954  ...            166.75                 49.254983
# 87595  ...            327.43                 49.064277
#
#            Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 9382    31 Years and 1 Months                   0.0          1634.213281
# 68000   25 Years and 5 Months                   0.0            74.732590
# 17029   21 Years and 9 Months                   0.0             0.000000
# 62954  25 Years and 11 Months                   NaN             0.000000
# 87595   20 Years and 0 Months                   0.0             0.000000
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 9382                188.162068  High_spent_Medium_value_payments
# 68000               121.328983   High_spent_Large_value_payments
# 17029               137.636169   High_spent_Large_value_payments
# 62954               183.280971   High_spent_Large_value_payments
# 87595               164.591576   High_spent_Large_value_payments
#
#        Monthly_Balance  Credit_Score  Credit_History_Age_in_Years
# 9382       1533.102266             1                    31.083333
# 68000      1552.946094             1                    25.416667
# 17029      1566.613165             2                    21.750000
# 62954      1542.274695             1                    25.916667
# 87595      1510.763424             1                    20.000000
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Payment_of_Min_Amount':
#         ID Customer_ID    Month    Name  Age          SSN Occupation  \
# 32  0x1632  CUS_0x1cdb  January  Deepaa   21  615-06-7821  Developer
# 34  0x1634  CUS_0x1cdb    March  Deepaa   21  615-06-7821  Developer
# 35  0x1635  CUS_0x1cdb    April  Deepaa   21  615-06-7821  Developer
# 36  0x1636  CUS_0x1cdb      May  Deepaa   21  615-06-7821  Developer
# 37  0x1637  CUS_0x1cdb     June  Deepaa   21  615-06-7821  Developer
#
#     Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 32       35547.71            2853.309167                  7  ...
# 34       35547.71            2853.309167                  7  ...
# 35       35547.71            2853.309167                  7  ...
# 36       35547.71            2853.309167                  7  ...
# 37       35547.71                    NaN                  7  ...
#
#     Outstanding_Debt  Credit_Utilization_Ratio      Credit_History_Age  \
# 32            943.86                 39.797764   30 Years and 8 Months
# 34            943.86                 23.462303  30 Years and 10 Months
# 35            943.86                 28.924954  30 Years and 11 Months
# 36            943.86                 41.776187   31 Years and 0 Months
# 37            943.86                 29.217556   31 Years and 1 Months
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 32                   1.0                  0.0               276.725394
# 34                   1.0                  0.0               173.138651
# 35                   1.0                  0.0                96.785485
# 36                   1.0                  0.0                62.723278
# 37                   1.0                  0.0                37.643638
#
#                    Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 32                            !@9#%8       288.605522             1
# 34   Low_spent_Medium_value_payments       392.192266             1
# 35  High_spent_Medium_value_payments       438.545432             1
# 36   High_spent_Small_value_payments       482.607638             1
# 37  High_spent_Medium_value_payments       497.687279             1
#
#     Credit_History_Age_in_Years
# 32                    30.666667
# 34                    30.833333
# 35                    30.916667
# 36                    31.000000
# 37                    31.083333
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Total_EMI_per_month':
#             ID Customer_ID  Month          Name  Age          SSN Occupation  \
# 87013  0x213d7  CUS_0x2a3a   June        Clarei   26  497-15-6884   Mechanic
# 15300   0x6fa6  CUS_0x36fb    May       Levineo   32  465-97-6079     Lawyer
# 29514   0xc2f0  CUS_0x1b8a  March         Ryanu   32  577-72-6050    Teacher
# 3084    0x2812  CUS_0x7812    May         Davev   21  992-47-8736  Scientist
# 51614  0x1446c  CUS_0x985e   July  David Jonesm   23  207-73-2763     Doctor
#
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 87013      15704.000            1606.519563                  6  ...
# 15300      20501.670                    NaN                  6  ...
# 29514      44927.860            3687.988333                  4  ...
# 3084       19653.005            1581.750417                  3  ...
# 51614      63983.160            5318.930000                  9  ...
#
#        Outstanding_Debt  Credit_Utilization_Ratio      Credit_History_Age  \
# 87013           2617.78                 32.167130   13 Years and 3 Months
# 15300           3373.13                 30.397662    9 Years and 2 Months
# 29514            762.62                 35.628503  20 Years and 11 Months
# 3084             919.98                 34.606272   17 Years and 8 Months
# 51614           3622.14                 37.865426   11 Years and 1 Months
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 87013                   NaN              82331.0                88.291602
# 15300                   1.0              82256.0                51.560372
# 29514                   0.0              82236.0               198.591737
# 3084                    0.0              82204.0               103.354231
# 51614                   1.0              82193.0                81.860988
#
#                      Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 87013   Low_spent_Small_value_payments       284.768410             0
# 15300   Low_spent_Large_value_payments       286.958740             0
# 29514  High_spent_Small_value_payments       328.016767             2
# 3084   Low_spent_Medium_value_payments       296.708255             2
# 51614  High_spent_Large_value_payments       500.971858             1
#
#        Credit_History_Age_in_Years
# 87013                    13.250000
# 15300                     9.166667
# 29514                    20.916667
# 3084                     17.666667
# 51614                    11.083333
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Amount_invested_monthly':
#          ID Customer_ID     Month       Name  Age          SSN    Occupation  \
# 18   0x161c  CUS_0x2dbc     March     Langep   34  486-85-3974       _______
# 23   0x1621  CUS_0x2dbc    August     Langep   34  486-85-3974      Engineer
# 28   0x162a  CUS_0xb891       May     Jasond   55  072-31-6145  Entrepreneur
# 121  0x16b7  CUS_0x33d2  February  Chalmersa   30  965-46-2491     Scientist
# 142  0x16d4   CUS_0xfdb      July   Patrickg   46  928-91-4452       Teacher
#
#      Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 18       143162.64                    NaN                  1  ...
# 23       143162.64           12187.220000                  1  ...
# 28        30689.89            2612.490833                  2  ...
# 121       31993.78            2942.148333                  6  ...
# 142       32284.62            2898.385000                  6  ...
#
#      Outstanding_Debt  Credit_Utilization_Ratio      Credit_History_Age  \
# 18            1303.01                 26.519815  17 Years and 11 Months
# 23            1303.01                 38.374753   18 Years and 4 Months
# 28             632.46                 41.154317   17 Years and 7 Months
# 121            818.22                 37.958569  16 Years and 11 Months
# 142           1283.37                 24.205533   6 Years and 11 Months
#
#     Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 18                    0.0           246.992319                  10000.0
# 23                    0.0           246.992319                  10000.0
# 28                    0.0            16.415452                  10000.0
# 121                   1.0            45.141298                  10000.0
# 142                   1.0           103.037560                  10000.0
#
#                    Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 18   High_spent_Small_value_payments       715.741367             2
# 23   High_spent_Small_value_payments       895.494583             1
# 28    Low_spent_Large_value_payments       359.374916             1
# 121   Low_spent_Small_value_payments       157.869804             1
# 142   Low_spent_Small_value_payments        85.902095             1
#
#      Credit_History_Age_in_Years
# 18                     17.916667
# 23                     18.333333
# 28                     17.583333
# 121                    16.916667
# 142                     6.916667
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Monthly_Balance':
#            ID Customer_ID    Month          Name  Age          SSN  \
# 9376   0x4cf2  CUS_0x3655  January     Ransdellw   29  512-00-8324
# 7475   0x41cd  CUS_0x6479    April         Oranw   33  219-01-0237
# 33072  0xd7ca  CUS_0x26fd  January      Lucianau   32  982-46-6532
# 17029  0x79c7  CUS_0x9f7a     June  Dave Clarkes   55  692-62-0934
# 15878  0x7308  CUS_0xa05d     July   Donny Kwokh   30  445-30-2049
#
#        Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 9376       Lawyer      177907.72           14712.643333                  0
# 7475   Accountant      177887.80           14828.983333                  4
# 33072   Scientist      178328.88           14771.740000                  4
# 17029      Writer      178793.92           14642.493333                  1
# 15878   Scientist      177546.36           14813.530000                  5
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio     Credit_History_Age  \
# 9376   ...            685.01                 39.432897  30 Years and 7 Months
# 7475   ...            925.47                 44.783892  26 Years and 7 Months
# 33072  ...            708.22                 40.541257  16 Years and 1 Months
# 17029  ...           1015.37                 49.522324  21 Years and 9 Months
# 15878  ...            715.97                 34.860662  30 Years and 4 Months
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 9376                    0.0                  0.0             10000.000000
# 7475                    0.0                  0.0               146.609398
# 33072                   0.0                  0.0               149.965691
# 17029                   0.0                  0.0               137.636169
# 15878                   0.0              50084.0               157.218174
#
#                      Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 9376   High_spent_Large_value_payments      1602.040519             0
# 7475   High_spent_Large_value_payments      1576.288935             1
# 33072  High_spent_Large_value_payments      1567.208309             2
# 17029  High_spent_Large_value_payments      1566.613165             2
# 15878                           !@9#%8      1564.134826             1
#
#        Credit_History_Age_in_Years
# 9376                     30.583333
# 7475                     26.583333
# 33072                    16.083333
# 17029                    21.750000
# 15878                    30.333333
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Credit_Score':
#        ID Customer_ID     Month           Name  Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh   23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh   23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh   23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh   23  821-00-0265  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0       19114.12            1824.843333                  3  ...
# 1       19114.12                    NaN                  3  ...
# 2       19114.12                    NaN                  3  ...
# 3       19114.12                    NaN                  3  ...
# 4       19114.12            1824.843333                  3  ...
#
#    Outstanding_Debt  Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                 26.822620  22 Years and 1 Months
# 1            809.98                 31.944960                    NaN
# 2            809.98                 28.609352  22 Years and 3 Months
# 3            809.98                 31.377862  22 Years and 4 Months
# 4            809.98                 24.797347  22 Years and 5 Months
#
#   Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                   0.0            49.574949                80.415295
# 1                   0.0            49.574949               118.280222
# 2                   0.0            49.574949                81.699521
# 3                   0.0            49.574949               199.458074
# 4                   0.0            49.574949                41.420153
#
#                   Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 0   High_spent_Small_value_payments       312.494089             2
# 1    Low_spent_Large_value_payments       284.629162             2
# 2   Low_spent_Medium_value_payments       331.209863             2
# 3    Low_spent_Small_value_payments       223.451310             2
# 4  High_spent_Medium_value_payments       341.489231             2
#
#    Credit_History_Age_in_Years
# 0                    22.083333
# 1                          NaN
# 2                    22.250000
# 3                    22.333333
# 4                    22.416667
#
# [5 rows x 29 columns]
# Top 5 rows with the highest values in column 'Credit_History_Age_in_Years':
#             ID Customer_ID   Month               Name  Age          SSN  \
# 775     0x1a89  CUS_0x3f04  August          Jenniferu   25  465-93-9571
# 31431   0xce29   CUS_0xfaf  August              Sveap   27  153-48-5124
# 33775   0xdbe5  CUS_0x19a3  August             Rigbyl   41  719-96-4265
# 37239   0xf031  CUS_0x9867  August           Nishantz   32    #F%$D@*&8
# 40663  0x10441  CUS_0xbf03  August  "Michael OBoyle"w   44  889-89-7508
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 775      _______      43758.340            3454.528333                  5
# 31431  Architect      39255.540            3546.295000                  4
# 33775     Lawyer      15636.605                    NaN                  8
# 37239  Architect     104506.980            8986.915000                  5
# 40663     Doctor      30231.090            2610.257500                  3
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio     Credit_History_Age  \
# 775    ...           1194.28                 35.742540  33 Years and 8 Months
# 31431  ...            536.03                 29.893853  33 Years and 8 Months
# 33775  ...            592.29                 33.461807  33 Years and 8 Months
# 37239  ...            684.55                 33.736034  33 Years and 8 Months
# 40663  ...           1263.11                 38.109592  33 Years and 8 Months
#
#       Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 775                     0.0            56.311421               364.237993
# 31431                   0.0            46.034586                53.697186
# 33775                   0.0            43.516348                57.445399
# 37239                   0.0           340.104957               628.926429
# 40663                   0.0            55.943907                65.314439
#
#                      Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 775     Low_spent_Small_value_payments       214.903420             2
# 31431  High_spent_Large_value_payments       494.897728             2
# 33775   Low_spent_Small_value_payments       346.543295             0
# 37239                           !@9#%8       219.660114             2
# 40663  High_spent_Large_value_payments       379.767404             1
#
#        Credit_History_Age_in_Years
# 775                      33.666667
# 31431                    33.666667
# 33775                    33.666667
# 37239                    33.666667
# 40663                    33.666667
#
# [5 rows x 29 columns]

# %%
print("==================================================================")
# Step 1: Remove the top 1% of rows with the highest annual income.
quantiles = df['Annual_Income'].quantile([0.25, 0.50, 0.75, 0.90, 0.95, 0.98, 0.99, 0.995, 0.998])
print("Annual Income Quantiles:")
print(quantiles)
q99 = quantiles[0.99]
df_filtered = df[df['Annual_Income'] <= q99].copy()
print(f"Rows remaining after filtering top 1% on annual income: {len(df_filtered)}")
print("==================================================================")

# Step 2: Remove the top 2% of rows with the most bank accounts.
quantiles = df_filtered['Num_Bank_Accounts'].quantile([0.25, 0.50, 0.75, 0.90, 0.95, 0.97, 0.98, 0.99, 0.995])
print("Number of Bank Accounts Quantiles:")
print(quantiles)
q98 = quantiles[0.98]
df_filtered = df_filtered[(df_filtered['Num_Bank_Accounts'] <= q98) & (df_filtered["Num_Bank_Accounts"] >= 0)]
print(f"Rows remaining after filtering top 2% on number of bank accounts: {len(df_filtered)}")
print("==================================================================")

# Step 3: Remove the top 3% of rows with the highest number of credit cards.
quantiles = df_filtered['Num_Credit_Card'].quantile([0.25, 0.50, 0.75, 0.90, 0.95, 0.96, 0.97, 0.98, 0.99, 0.995])
print("Number of Credit Card Quantiles:")
print(quantiles)
q97 = quantiles[0.97]
df_filtered = df_filtered[(df_filtered['Num_Credit_Card'] <= q97) & (df_filtered["Num_Credit_Card"] >= 0)]
print(f"Rows remaining after filtering top 3% on number of credit cards: {len(df_filtered)}")
print("==================================================================")

# Step 4: Remove the top 2% of rows with the most credit inquiries.
quantiles = df_filtered['Num_Credit_Inquiries'].quantile([0.25, 0.50, 0.75, 0.90, 0.95, 0.96, 0.97, 0.98, 0.99, 0.995])
print("Number of Credit Inquiries Quantiles:")
print(quantiles)
q98 = quantiles[0.98]
df_filtered = df_filtered[(df_filtered['Num_Credit_Inquiries'] <= q98) & (df_filtered["Num_Credit_Inquiries"] >= 0)]
print(f"Rows remaining after filtering top 2% on number of credit inquiries: {len(df_filtered)}")
print("==================================================================")

# Step 5: Remove the top 0.47% of rows with the most loans.
quantiles = df_filtered['Num_of_Loan'].quantile([0.25, 0.50, 0.75, 0.90, 0.97, 0.98, 0.99, 0.995, 0.9951, 0.9953, 0.9954, 0.996, 0.998])
print("Number of Loans Quantiles:")
print(quantiles)
q9953 = quantiles[0.9953]
df_filtered = df_filtered[(df_filtered['Num_of_Loan'] <= q9953) & (df_filtered["Num_of_Loan"] >= 0)]
print(f"Rows remaining after filtering top 0.47% on number of loans: {len(df_filtered)}")
print("==================================================================")

# Step 6: Remove the top 0.8% of rows with the highest number of delayed payments.
quantiles = df_filtered['Num_of_Delayed_Payment'].quantile([0.25, 0.50, 0.75, 0.90, 0.97, 0.98, 0.99, 0.991, 0.992, 0.993, 0.995])
print("Number of Delayed Payments Quantiles:")
print(quantiles)
q992 = quantiles[0.992]
df_filtered = df_filtered[(df_filtered['Num_of_Delayed_Payment'] <= q992) & (df_filtered["Num_of_Delayed_Payment"] >= 0)]
print(f"Rows remaining after filtering top 0.8% on number of delayed payments: {len(df_filtered)}")
print("==================================================================")

# Step 7: Filter out rows with negative monthly balance values.
quantiles = df_filtered['Monthly_Balance'].quantile([0.25, 0.50, 0.75, 0.90, 0.97, 0.98, 0.99, 0.991, 0.992, 0.993, 0.995, 0.998, 0.9999])
print("Monthly Balance Quantiles:")
print(quantiles)
df_filtered = df_filtered[(df_filtered["Monthly_Balance"] >= 0)]
print(f"Rows remaining after filtering on monthly balance: {len(df_filtered)}")
print("==================================================================")

# Step 8: Handle abnormal values in age by setting out-of-range ages to NaN and interpolating.
df_filtered.loc[(df_filtered['Age'] < 0) | (df_filtered['Age'] > 100), 'Age'] = pd.NA
df_filtered['Age'] = df_filtered.groupby('Name')['Age'].transform(lambda x: x.interpolate(method='linear'))
print("Handled abnormal age values with interpolation where possible.")
print("==================================================================")

# Step 9: Fill missing values for Monthly Inhand Salary using linear interpolation.
df_filtered['Monthly_Inhand_Salary'] = df_filtered.groupby('Name')['Monthly_Inhand_Salary'].transform(lambda x: x.interpolate(method='linear'))

# Step 10: Drop rows with missing values in Age, Outstanding Debt, and Monthly Balance.
df_filtered.dropna(subset=["Age", "Outstanding_Debt", "Monthly_Balance"], inplace=True)
print(f"Rows remaining after dropping rows with missing values in critical fields: {len(df_filtered)}")
print("==================================================================")

df_filtered.head()
# Out:
# ==================================================================
# Annual Income Quantiles:
# 0.250    1.945750e+04
# 0.500    3.757861e+04
# 0.750    7.279092e+04
# 0.900    1.130859e+05
# 0.950    1.345333e+05
# 0.980    1.668376e+05
# 0.990    1.799873e+05
# 0.995    1.292096e+07
# 0.998    1.964043e+07
# Name: Annual_Income, dtype: float64
# Rows remaining after filtering top 1% on annual income: 99001
# ==================================================================
# Number of Bank Accounts Quantiles:
# 0.250       3.0
# 0.500       6.0
# 0.750       7.0
# 0.900       9.0
# 0.950      10.0
# 0.970      10.0
# 0.980      10.0
# 0.990     446.0
# 0.995    1096.0
# Name: Num_Bank_Accounts, dtype: float64
# Rows remaining after filtering top 2% on number of bank accounts: 97670
# ==================================================================
# Number of Credit Card Quantiles:
# 0.250       4.0
# 0.500       5.0
# 0.750       7.0
# 0.900       9.0
# 0.950      10.0
# 0.960      10.0
# 0.970      10.0
# 0.980     172.0
# 0.990     849.0
# 0.995    1177.0
# Name: Num_Credit_Card, dtype: float64
# Rows remaining after filtering top 3% on number of credit cards: 95417
# ==================================================================
# Number of Credit Inquiries Quantiles:
# 0.250       3.000
# 0.500       6.000
# 0.750       9.000
# 0.900      12.000
# 0.950      13.000
# 0.960      14.000
# 0.970      15.000
# 0.980      16.000
# 0.990    1113.000
# 0.995    1816.245
# Name: Num_Credit_Inquiries, dtype: float64
# Rows remaining after filtering top 2% on number of credit inquiries: 91702
# ==================================================================
# Number of Loans Quantiles:
# 0.2500      1.0000
# 0.5000      3.0000
# 0.7500      5.0000
# 0.9000      7.0000
# 0.9700      9.0000
# 0.9800      9.0000
# 0.9900      9.0000
# 0.9950      9.0000
# 0.9951      9.0000
# 0.9953     19.0212
# 0.9954     34.0524
# 0.9960    209.3720
# 0.9980    867.5980
# Name: Num_of_Loan, dtype: float64
# Rows remaining after filtering top 0.47% on number of loans: 87712
# ==================================================================
# Number of Delayed Payments Quantiles:
# 0.250       9.000
# 0.500      14.000
# 0.750      18.000
# 0.900      21.000
# 0.970      25.000
# 0.980      25.000
# 0.990      27.000
# 0.991      28.000
# 0.992      28.000
# 0.993     553.585
# 0.995    1716.620
# Name: Num_of_Delayed_Payment, dtype: float64
# Rows remaining after filtering top 0.8% on number of delayed payments: 80422
# ==================================================================
# Monthly Balance Quantiles:
# 0.2500     269.931195
# 0.5000     336.623402
# 0.7500     469.535639
# 0.9000     706.471273
# 0.9700     962.700085
# 0.9800    1030.694032
# 0.9900    1135.144401
# 0.9910    1149.038144
# 0.9920    1169.508468
# 0.9930    1185.053342
# 0.9950    1228.837697
# 0.9980    1328.940394
# 0.9999    1533.810717
# Name: Monthly_Balance, dtype: float64
# Rows remaining after filtering on monthly balance: 79456
# ==================================================================
# Handled abnormal age values with interpolation where possible.
# ==================================================================
# Rows remaining after dropping rows with missing values in critical fields: 71195
# ==================================================================
#        ID Customer_ID    Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40  January  Aaron Maashoh  23.0  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40    March  Aaron Maashoh  23.0  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40    April  Aaron Maashoh  23.0  821-00-0265  Scientist
# 5  0x1607   CUS_0xd40     June  Aaron Maashoh  23.0  821-00-0265  Scientist
# 6  0x1608   CUS_0xd40     July  Aaron Maashoh  23.0  821-00-0265  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0       19114.12            1824.843333                  3  ...
# 2       19114.12            1824.843333                  3  ...
# 3       19114.12            1824.843333                  3  ...
# 5       19114.12            1824.843333                  3  ...
# 6       19114.12            1824.843333                  3  ...
#
#    Outstanding_Debt  Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                 26.822620  22 Years and 1 Months
# 2            809.98                 28.609352  22 Years and 3 Months
# 3            809.98                 31.377862  22 Years and 4 Months
# 5            809.98                 27.262259  22 Years and 6 Months
# 6            809.98                 22.537593  22 Years and 7 Months
#
#   Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                   0.0            49.574949                80.415295
# 2                   0.0            49.574949                81.699521
# 3                   0.0            49.574949               199.458074
# 5                   0.0            49.574949                62.430172
# 6                   0.0            49.574949               178.344067
#
#                  Payment_Behaviour  Monthly_Balance  Credit_Score  \
# 0  High_spent_Small_value_payments       312.494089             2
# 2  Low_spent_Medium_value_payments       331.209863             2
# 3   Low_spent_Small_value_payments       223.451310             2
# 5                           !@9#%8       340.479212             2
# 6   Low_spent_Small_value_payments       244.565317             2
#
#    Credit_History_Age_in_Years
# 0                    22.083333
# 2                    22.250000
# 3                    22.333333
# 5                    22.500000
# 6                    22.583333
#
# [5 rows x 29 columns]

# %%
df_filtered.describe()
# Out:
#                 Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  71195.000000   71195.000000           69473.000000       71195.000000
# mean      33.259351   49955.303393            4150.177920           5.380799
# std       10.764095   37990.562976            3151.831740           2.579236
# min       14.000000    7005.930000             303.645417           0.000000
# 25%       24.000000   19253.600000            1623.130833           3.000000
# 50%       33.000000   36665.050000            3060.806667           6.000000
# 75%       42.000000   70981.160000            5902.315000           7.000000
# max       99.000000  179987.280000           15204.633333          10.000000
#
#        Num_Credit_Card  Interest_Rate   Num_of_Loan  Delay_from_due_date  \
# count     71195.000000   71195.000000  71195.000000         71195.000000
# mean          5.535529      73.470735      3.521806            21.101650
# std           2.057960     472.430657      2.438492            14.830203
# min           0.000000       1.000000      0.000000            -5.000000
# 25%           4.000000       8.000000      2.000000            10.000000
# 50%           5.000000      14.000000      3.000000            18.000000
# 75%           7.000000      20.000000      5.000000            28.000000
# max          10.000000    5789.000000     19.000000            67.000000
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# count            71195.000000          69674.000000          71195.000000
# mean                13.398820             10.399412              5.771964
# std                  6.198585              6.784703              3.816074
# min                  0.000000             -6.490000              0.000000
# 25%                  9.000000              5.320000              3.000000
# 50%                 14.000000              9.430000              5.000000
# 75%                 18.000000             14.900000              8.000000
# max                 28.000000             36.490000             16.000000
#
#        Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# count         0.0      71195.000000              71195.000000
# mean          NaN       1424.335290                 32.322550
# std           NaN       1151.917196                  5.110329
# min           NaN          0.230000                 20.881250
# 25%           NaN        566.080000                 28.105929
# 50%           NaN       1166.370000                 32.342886
# 75%           NaN       1945.670000                 36.531702
# max           NaN       4998.070000                 49.564519
#
#        Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# count           62682.000000         71195.000000             68006.000000
# mean                0.598050          1448.742330               623.274158
# std                 0.490296          8457.033796              2029.285101
# min                 0.000000             0.000000                 0.000000
# 25%                 0.000000            30.088722                73.763927
# 50%                 1.000000            68.410772               133.726879
# 75%                 1.000000           156.003312               257.168215
# max                 1.000000         82331.000000             10000.000000
#
#        Monthly_Balance  Credit_Score  Credit_History_Age_in_Years
# count     71195.000000  71195.000000                 64783.000000
# mean        401.809416      0.884472                    18.436698
# std         213.226227      0.673323                     8.313855
# min           0.088628      0.000000                     0.083333
# 25%         269.761165      0.000000                    12.000000
# 50%         336.584352      1.000000                    18.333333
# 75%         468.986526      1.000000                    25.166667
# max        1602.040519      2.000000                    33.666667

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Single Column Distributions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

avg_age_per_person = df_filtered.groupby('Name')['Age'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(avg_age_per_person, kde=True, bins=10)
plt.title('Average Age Distribution per Person')
plt.xlabel('Average Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
avg_aincome_pperson = df_filtered.groupby('Name')['Annual_Income'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(avg_aincome_pperson, kde=True)
plt.title('Average Annual Income Distribution per Person')
plt.xlabel('Average Annual Income')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
avg_monthly_inhand_salary_pperson = df_filtered.groupby('Name')['Monthly_Inhand_Salary'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(avg_monthly_inhand_salary_pperson, kde=True)
plt.title('Average Monthly_Inhand_Salary Distribution per Person')
plt.xlabel('Average Monthly_Inhand_Salary')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
avg_num_bank_account_pperson = df_filtered.groupby('Name')['Num_Bank_Accounts'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(avg_num_bank_account_pperson, bins=10)
plt.title('Average Num of Bank Accounts Distribution per Person')
plt.xlabel('Average Num of Bank Accounts')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
avg_num_credit_card_pperson = df_filtered.groupby('Name')['Num_Credit_Card'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(avg_num_credit_card_pperson, bins=10)
plt.title('Average Num of Credit Cards Distribution per Person')
plt.xlabel('Average Num of Credit Cards')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
avg_num_loan_pperson = df_filtered.groupby('Name')['Num_of_Loan'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(avg_num_loan_pperson, bins=10)
plt.title('Average Num of Loan Distribution per Person')
plt.xlabel('Average Num of Loan')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
avg_delay_from_due_date_pperson = df_filtered.groupby('Name')['Delay_from_due_date'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(avg_delay_from_due_date_pperson, bins=10, kde=True)
plt.title('Average Delay from Due Date Distribution per Person')
plt.xlabel('Average Delay from Due Date')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
avg_num_delayed_payment_pperson = df_filtered.groupby('Name')['Num_of_Delayed_Payment'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(avg_num_delayed_payment_pperson, bins=9, kde=True)
plt.title('Average Num of Delayed Payment Distribution per Person')
plt.xlabel('Average Num of Delayed Payment')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
avg_num_credit_inquiries_pperson = df_filtered.groupby('Name')['Num_Credit_Inquiries'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(avg_num_credit_inquiries_pperson, bins=10, kde=True)
plt.title('Average Num of Credit Inquiries Distribution per Person')
plt.xlabel('Average Num of Credit Inquiries')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
avg_outstanding_debt_pperson = df_filtered.groupby('Name')['Outstanding_Debt'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(avg_outstanding_debt_pperson, bins=10, kde=True)
plt.title('Average Outstanding Debt Distribution per Person')
plt.xlabel('Average Outstanding Debt')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
avg_credit_util_ratio_pperson = df_filtered.groupby('Name')['Credit_Utilization_Ratio'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(avg_credit_util_ratio_pperson, bins=10, kde=True)
plt.title('Average Credit Utilization Ratio Distribution per Person')
plt.xlabel('Average Credit Utilization Ratio')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
avg_credit_history_age_pperson = df_filtered.groupby('Name')['Credit_History_Age_in_Years'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(avg_credit_history_age_pperson, bins=10, kde=True)
plt.title('Average Credit History Age Distribution per Person')
plt.xlabel('Average Credit History Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
avg_credit_history_age_pperson = df_filtered.groupby('Name')['Payment_of_Min_Amount'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(avg_credit_history_age_pperson, bins=5)
plt.title('Distribution of Payment_of_Min_Amount')
plt.xlabel('Payment_of_Min_Amount')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
avg_monthly_investment_pperson = df_filtered.groupby('Name')['Amount_invested_monthly'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(avg_monthly_investment_pperson, bins=20, kde=True)
plt.title('Distribution of Average Monthly Investment')
plt.xlabel('Monthly Investment')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
avg_monthly_balance_pperson = df_filtered.groupby('Name')['Monthly_Balance'].mean()

plt.figure(figsize=(10, 6))
sns.histplot(avg_monthly_balance_pperson, bins=20, kde=True)
plt.title('Distribution of Monthly Balance')
plt.xlabel('Monthly Balance')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
credit_score_pperson = df_filtered['Credit_Score']

plt.figure(figsize=(10, 6))
sns.histplot(credit_score_pperson, bins=3)
plt.title('Distribution of Credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Frequency')
plt.show()
# Out:
# e:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Bivariate Distribution Plot

# %%
df_numeric = df_filtered.select_dtypes(include=['float64', 'int64'])
correlation_matrix = df_numeric.corr()

plt.figure(figsize=(20, 10))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation heatmap")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x=credit_score_pperson, y=df_filtered["Annual_Income"])
plt.title('Annual Income Distribution by Credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Annual Income')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x=credit_score_pperson, y=df_filtered["Credit_History_Age_in_Years"])
plt.title('Credit History Age Distribution by Credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Credit History Age')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=credit_score_pperson, y=df_filtered["Num_Credit_Card"])
plt.title('Number of Credit Card Distribution by Credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Number of Credit Card')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=credit_score_pperson, y=df_filtered["Num_Credit_Inquiries"])
plt.title('Number of Credit Inquiries Distribution by Credit Score')
plt.xlabel('Credit Score')
plt.ylabel('Number of Credit Inquiries')
plt.show()

# %%
plt.figure(figsize=(10, 6))
cross_tab = pd.crosstab(credit_score_pperson, df_filtered["Payment_of_Min_Amount"])

sns.heatmap(cross_tab, annot=True, fmt="d", cmap="plasma")
plt.title("Credit Score vs Minimum Payment Status")
plt.xlabel("Minimum Payment Status")
plt.ylabel("Credit Score")
plt.show()

# %% [markdown]
# ## Model Training

# %%
back_df = df_filtered.copy()
back_df
# Out:
#             ID Customer_ID    Month           Name   Age          SSN  \
# 0       0x1602   CUS_0xd40  January  Aaron Maashoh  23.0  821-00-0265
# 3       0x1605   CUS_0xd40    April  Aaron Maashoh  23.0  821-00-0265
# 5       0x1607   CUS_0xd40     June  Aaron Maashoh  23.0  821-00-0265
# 6       0x1608   CUS_0xd40     July  Aaron Maashoh  23.0  821-00-0265
# 7       0x1609   CUS_0xd40   August            NaN  23.0    #F%$D@*&8
# ...        ...         ...      ...            ...   ...          ...
# 99994  0x25fe8  CUS_0x942c    March          Nicks  25.0  078-73-5990
# 99995  0x25fe9  CUS_0x942c    April          Nicks  25.0  078-73-5990
# 99996  0x25fea  CUS_0x942c      May          Nicks  25.0  078-73-5990
# 99997  0x25feb  CUS_0x942c     June          Nicks  25.0  078-73-5990
# 99999  0x25fed  CUS_0x942c   August          Nicks  25.0  078-73-5990
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0      Scientist       19114.12            1824.843333                3.0
# 3      Scientist       19114.12                    NaN                3.0
# 5      Scientist       19114.12                    NaN                3.0
# 6      Scientist       19114.12            1824.843333                3.0
# 7      Scientist       19114.12            1824.843333                3.0
# ...          ...            ...                    ...                ...
# 99994   Mechanic       39628.99            3359.415833                4.0
# 99995   Mechanic       39628.99            3359.415833                4.0
# 99996   Mechanic       39628.99            3359.415833                4.0
# 99997   Mechanic       39628.99            3359.415833                4.0
# 99999   Mechanic       39628.99            3359.415833                4.0
#
#        ...  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0      ...            809.98                 26.822620
# 3      ...            809.98                 31.377862
# 5      ...            809.98                 27.262259
# 6      ...            809.98                 22.537593
# 7      ...            809.98                 23.933795
# ...    ...               ...                       ...
# 99994  ...            502.38                 39.323569
# 99995  ...            502.38                 34.663572
# 99996  ...            502.38                 40.565631
# 99997  ...            502.38                 41.255522
# 99999  ...            502.38                 34.192463
#
#            Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 0       22 Years and 1 Months                   0.0            49.574949
# 3       22 Years and 4 Months                   0.0            49.574949
# 5       22 Years and 6 Months                   0.0            49.574949
# 6       22 Years and 7 Months                   0.0            49.574949
# 7                         NaN                   0.0            49.574949
# ...                       ...                   ...                  ...
# 99994   31 Years and 5 Months                   0.0            35.104023
# 99995   31 Years and 6 Months                   0.0            35.104023
# 99996   31 Years and 7 Months                   0.0            35.104023
# 99997   31 Years and 8 Months                   0.0            35.104023
# 99999  31 Years and 10 Months                   0.0            35.104023
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 0                    80.415295   High_spent_Small_value_payments
# 3                   199.458074    Low_spent_Small_value_payments
# 5                    62.430172                            !@9#%8
# 6                   178.344067    Low_spent_Small_value_payments
# 7                    24.785217  High_spent_Medium_value_payments
# ...                        ...                               ...
# 99994               140.581403  High_spent_Medium_value_payments
# 99995                60.971333   High_spent_Large_value_payments
# 99996                54.185950  High_spent_Medium_value_payments
# 99997                24.028477   High_spent_Large_value_payments
# 99999               167.163865                            !@9#%8
#
#        Monthly_Balance  Credit_Score  Credit_History_Age_in_Years
# 0           312.494089           2.0                    22.083333
# 3           223.451310           2.0                    22.333333
# 5           340.479212           2.0                    22.500000
# 6           244.565317           2.0                    22.583333
# 7           358.124168           1.0                          NaN
# ...                ...           ...                          ...
# 99994       410.256158           0.0                    31.416667
# 99995       479.866228           0.0                    31.500000
# 99996       496.651610           0.0                    31.583333
# 99997       516.809083           0.0                    31.666667
# 99999       393.673696           0.0                    31.833333
#
# [77234 rows x 29 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

df_filtered = back_df.copy()
dict = {
    'High_spent_Small_value_payments' : 0,
    'Low_spent_Large_value_payments' : 1,
    'Low_spent_Medium_value_payments' : 2,
    'Low_spent_Small_value_payments' : 3,
    'High_spent_Medium_value_payments' : 4,
    'High_spent_Large_value_payments': 5,
    '!@9#%8' : np.nan
}

df_filtered['Payment_Behaviour'] = df_filtered['Payment_Behaviour'].map(dict)
label_encoder = LabelEncoder()

df_filtered["Occupation"] = label_encoder.fit_transform(df_filtered["Occupation"])
df_filtered["Credit_Mix"] = label_encoder.fit_transform(df_filtered["Credit_Mix"])
df_filtered["Payment_of_Min_Amount"] = label_encoder.fit_transform(df_filtered["Payment_of_Min_Amount"])

df_filtered.drop("ID", axis=1, inplace=True)
df_filtered.drop("Name", axis=1, inplace=True)
df_filtered.drop("Customer_ID", axis=1, inplace=True)
df_filtered.drop("SSN", axis=1, inplace=True)
df_filtered.drop("Type_of_Loan", axis=1, inplace=True)
df_filtered.drop("Monthly_Inhand_Salary", axis=1, inplace=True)
df_filtered.drop("Credit_History_Age", axis=1, inplace=True)
df_filtered.drop("Month", axis=1, inplace=True)
df_filtered.drop(['Monthly_Balance', 'Credit_Utilization_Ratio', "Interest_Rate"], axis=1, inplace=True)
print(df_filtered.isna().sum())
# Out:
# Age                               0
# Occupation                        0
# Annual_Income                     0
# Num_Bank_Accounts                 0
# Num_Credit_Card                   0
# Num_of_Loan                       0
# Delay_from_due_date               0
# Num_of_Delayed_Payment            0
# Changed_Credit_Limit           1641
# Num_Credit_Inquiries              0
# Credit_Mix                        0
# Outstanding_Debt                  0
# Payment_of_Min_Amount             0
# Total_EMI_per_month               0
# Amount_invested_monthly        3435
# Payment_Behaviour              5806
# Credit_Score                      0
# Credit_History_Age_in_Years    6978
# dtype: int64

# %%
from imblearn.over_sampling import SMOTE

df_filtered = df_filtered.dropna()

X = df_filtered.drop(['Credit_Score'], axis=1)
sc = StandardScaler()
X_scaled = sc.fit_transform(X)
y = df_filtered['Credit_Score']
X = pd.DataFrame(X_scaled, columns=X.columns)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
sm = SMOTE(k_neighbors=7)
X_train_sm, y_train_sm = sm.fit_resample(X_train, y_train)

# %%
# !pip install pycaret[full]

# %%
from pycaret.classification import *
import pycaret

s = setup(X_train_sm, target = y_train_sm,normalize=True)
# Out:
# <style type="text/css">
# #T_7e831_row8_col1, #T_7e831_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7e831" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e831_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7e831_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e831_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e831_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7e831_row0_col1" class="data row0 col1" >4986</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7e831_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7e831_row1_col1" class="data row1 col1" >Credit_Score</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7e831_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_7e831_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7e831_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_7e831_row3_col1" class="data row3 col1" >(87663, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7e831_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_7e831_row4_col1" class="data row4 col1" >(87663, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7e831_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_7e831_row5_col1" class="data row5 col1" >(61364, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7e831_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_7e831_row6_col1" class="data row6 col1" >(26299, 18)</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7e831_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_7e831_row7_col1" class="data row7 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7e831_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_7e831_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7e831_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_7e831_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7e831_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_7e831_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7e831_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_7e831_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7e831_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_7e831_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7e831_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_7e831_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7e831_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_7e831_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7e831_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_7e831_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7e831_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_7e831_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7e831_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_7e831_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7e831_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_7e831_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7e831_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_7e831_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7e831_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7e831_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_7e831_row20_col1" class="data row20 col1" >8cf5</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models(include=['et'])
plot_model(best_model, plot = 'confusion_matrix')
save_model(best_model, 'best_model')
# Out:
# <style type="text/css">
# #T_4a483 th {
#   text-align: left;
# }
# #T_4a483_row0_col0 {
#   text-align: left;
# }
# #T_4a483_row0_col1, #T_4a483_row0_col2, #T_4a483_row0_col3, #T_4a483_row0_col4, #T_4a483_row0_col5, #T_4a483_row0_col6, #T_4a483_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4a483_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4a483" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a483_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4a483_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_4a483_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_4a483_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_4a483_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_4a483_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_4a483_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_4a483_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_4a483_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a483_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_4a483_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_4a483_row0_col1" class="data row0 col1" >0.8540</td>
#       <td id="T_4a483_row0_col2" class="data row0 col2" >0.9498</td>
#       <td id="T_4a483_row0_col3" class="data row0 col3" >0.8540</td>
#       <td id="T_4a483_row0_col4" class="data row0 col4" >0.8530</td>
#       <td id="T_4a483_row0_col5" class="data row0 col5" >0.8526</td>
#       <td id="T_4a483_row0_col6" class="data row0 col6" >0.7810</td>
#       <td id="T_4a483_row0_col7" class="data row0 col7" >0.7817</td>
#       <td id="T_4a483_row0_col8" class="data row0 col8" >11.3300</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/9 [00:00<?, ?it/s]
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Age', 'Occupation',
#                                               'Annual_Income',
#                                               'Num_Bank_Accounts',
#                                               'Num_Credit_Card', 'Num_of_Loan',
#                                               'Delay_from_due_date',
#                                               'Num_of_Delayed_Payment',
#                                               'Changed_Credit_Limit',
#                                               'Num_Credit_Inquiries',
#                                               'Credit_Mix', 'Outstanding_Debt',
#                                               'Payment_of_Min_Amount',
#                                               'Total_...
#                   ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                                        class_weight=None, criterion='gini',
#                                        max_depth=None, max_features='sqrt',
#                                        max_leaf_nodes=None, max_samples=None,
#                                        min_impurity_decrease=0.0,
#                                        min_samples_leaf=1, min_samples_split=2,
#                                        min_weight_fraction_leaf=0.0,
#                                        monotonic_cst=None, n_estimators=100,
#                                        n_jobs=-1, oob_score=False,
#                                        random_state=4986, verbose=0,
#                                        warm_start=False))],
#           verbose=False),
#  'best_model.pkl')

# %% [markdown]
# ## Search for Feature Values Using Bayesian Optimization

# %%
best_model = load_model('best_model')

# %%
from hyperopt import fmin, tpe, hp, Trials

def objective(params):
    modified_sample = current_sample.copy()
    for feature, value in params.items():
        modified_sample[feature] = value
    modified_sample_df = pd.DataFrame([modified_sample])
    pred = best_model.predict(modified_sample_df)[0]
    return 2 - pred

current_sample = X_test.iloc[3]

max_values = X_train.max()
min_values = X_train.min()
correlation_matrix = df_filtered.corr()

epsilon = 1e-4

# %%
best_model.predict(X_test.iloc[3].values.reshape(1, -1)), y_test.iloc[3]
# Out:
# (array([0.], dtype=float32), 0.0)

# %% [markdown]
# ### Search each feature value individually

# %%
space = {}
for feature in current_sample.index:
    if feature not in correlation_matrix["Credit_Score"]:
        print(f"Feature {feature} not found in correlation_matrix")
        continue
    elif feature == "Interest_Rate" or feature == "Age" or feature == "Occupation":
        print(f"Feature {feature} will not be included in the search space.")
        continue
    correlation = correlation_matrix["Credit_Score"][feature]

    if feature == "Payment_of_Min_Amount":
        space[feature] = hp.choice(feature, [0, 1])
    # elif "Num_" in feature:
    #     if correlation > 0:
    #         space = {feature: hp.quniform(feature, current_sample[feature], max(max_values[feature], current_sample[feature] + epsilon), 1)}
    #     else:
    #         space = {feature: hp.quniform(feature, min(min_values[feature], current_sample[feature] - epsilon), current_sample[feature], 1)}
    else:
        if correlation > 0:
            space = {feature: hp.uniform(feature, current_sample[feature], max(max_values[feature], current_sample[feature] + epsilon))}
        else:
            space = {feature: hp.uniform(feature, min(min_values[feature], current_sample[feature] - epsilon), current_sample[feature])}

    trials = Trials()
    best_params = fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=100,
        trials=trials
    )

    for feature_name, scaled_values in best_params.items():
        mean = sc.mean_[X.columns.get_loc(feature_name)]
        scale = sc.scale_[X.columns.get_loc(feature_name)]

        original_values = scaled_values * scale + mean
        print(f"Optimized parameters to reach 'Good': {feature_name}: {original_values}", )
# Out:
# Feature Age will not be included in the search space.
# Feature Occupation will not be included in the search space.
#  44%|████▍     | 44/100 [00:02<00:02, 20.25trial/s, best loss: 2.0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-b7fa0d46fa60> in <cell line: 2>()
#      23
#      24     trials = Trials()
# ---> 25     best_params = fmin(
#      26         fn=objective,
#      27         space=space,
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     538
#     539     if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540         return trials.fmin(
#     541             fn,
#     542             space,
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/base.py in fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     669         from .fmin import fmin
#     670
# --> 671         return fmin(
#     672             fn,
#     673             space,
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     584
#     585     # next line is where the fmin is actually executed
# --> 586     rval.exhaust()
#     587
#     588     if return_argmin:
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in exhaust(self)
#     362     def exhaust(self):
#     363         n_done = len(self.trials)
# --> 364         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365         self.trials.refresh()
#     366         return self
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in run(self, N, block_until_done)
#     298                 else:
#     299                     # -- loop over trials and do the jobs directly
# --> 300                     self.serial_evaluate()
#     301
#     302                 self.trials.refresh()
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in serial_evaluate(self, N)
#     176                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177                 try:
# --> 178                     result = self.domain.evaluate(spec, ctrl)
#     179                 except Exception as e:
#     180                     logger.error("job exception: %s" % str(e))
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/base.py in evaluate(self, config, ctrl, attach_attachments)
#     890                 print_node_on_error=self.rec_eval_print_node_on_error,
#     891             )
# --> 892             rval = self.fn(pyll_rval)
#     893
#     894         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-64-117cce5ac010> in objective(params)
#       6         modified_sample[feature] = value
#       7     modified_sample_df = pd.DataFrame([modified_sample])
# ----> 8     pred = best_model.predict(modified_sample_df)[0]
#       9     return 2 - pred
#      10
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     903             The predicted classes.
#     904         """
# --> 905         proba = self.predict_proba(X)
#     906
#     907         if self.n_outputs_ == 1:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in predict_proba(self, X)
#     956         ]
#     957         lock = threading.Lock()
# --> 958         Parallel(n_jobs=n_jobs, verbose=self.verbose, require="sharedmem")(
#     959             delayed(_accumulate_prediction)(e.predict_proba, X, all_proba, lock)
#     960             for e in self.estimators_
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      65             for delayed_func, args, kwargs in iterable
#      66         )
# ---> 67         return super().__call__(iterable_with_config)
#      68
#      69
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1950         next(output)
#    1951
# -> 1952         return output if self.return_generator else list(output)
#    1953
#    1954     def __repr__(self):
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1593
#    1594             with self._backend.retrieval_context():
# -> 1595                 yield from self._retrieve()
#    1596
#    1597         except GeneratorExit:
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _retrieve(self)
#    1705                 (self._jobs[0].get_status(
#    1706                     timeout=self.timeout) == TASK_PENDING)):
# -> 1707                 time.sleep(0.01)
#    1708                 continue
#    1709
#
# KeyboardInterrupt:

# %% [markdown]
# ### Gradually add feature values to the search space

# %%
space = {}
for feature in current_sample.index:
    if feature not in correlation_matrix["Credit_Score"] or feature == "Interest_Rate" or feature == "Age" or feature == "Occupation":
        print(f"Feature {feature} not found in correlation_matrix")
        continue
    correlation = correlation_matrix["Credit_Score"][feature]

    if feature == "Payment_of_Min_Amount":
        space[feature] = hp.choice(feature, [0, 1])
    elif "Num_" in feature:
        if correlation > 0:
            space[feature] = hp.quniform(feature, current_sample[feature], max(max_values[feature], current_sample[feature] + epsilon), 1)
        else:
            space[feature] = hp.quniform(feature, min(min_values[feature], current_sample[feature] - epsilon), current_sample[feature], 1)
    else:
        if correlation > 0:
            space[feature] = hp.uniform(feature, current_sample[feature], max(max_values[feature], current_sample[feature] + epsilon))
        else:
            space[feature] = hp.uniform(feature, min(min_values[feature], current_sample[feature] - epsilon), current_sample[feature])

    trials = Trials()
    best_params = fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=500,
        trials=trials
    )

    print(f"Optimized parameters to reach 'Good': ")
    for feature_name, scaled_values in best_params.items():
        mean = sc.mean_[X.columns.get_loc(feature_name)]
        scale = sc.scale_[X.columns.get_loc(feature_name)]

        original_values = scaled_values * scale + mean
        print(f"{feature_name}: {original_values}")
# Out:
# Feature Age not found in correlation_matrix
# 100%|██████████| 100/100 [00:03<00:00, 25.19trial/s, best loss: 2.0]
# Optimized parameters to reach 'Good':
# Occupation: 3.5455550647031524
# 100%|██████████| 100/100 [00:03<00:00, 25.52trial/s, best loss: 2.0]
# Optimized parameters to reach 'Good':
# Annual_Income: 133491.52333103446
# Occupation: 4.854704866373696
# 100%|██████████| 100/100 [00:08<00:00, 11.24trial/s, best loss: 2.0]
# Optimized parameters to reach 'Good':
# Annual_Income: 102199.48589629476
# Num_Bank_Accounts: 2.7983399440903947
# Occupation: 2.100926298699049
# 100%|██████████| 100/100 [00:04<00:00, 20.38trial/s, best loss: 1.0]
# Optimized parameters to reach 'Good':
# Annual_Income: 167081.37857228593
# Num_Bank_Accounts: 0.21478779166675022
# Num_Credit_Card: 1.4188387995501683
# Occupation: 0.06138939296970847
# 100%|██████████| 100/100 [00:06<00:00, 14.79trial/s, best loss: 1.0]
# Optimized parameters to reach 'Good':
# Annual_Income: 122970.16329862578
# Num_Bank_Accounts: 2.7983399440903947
# Num_Credit_Card: 5.53722966522927
# Num_of_Loan: 5.9572538691505645
# Occupation: 3.178633807150362
# 100%|██████████| 100/100 [00:04<00:00, 20.36trial/s, best loss: 1.0]
# Optimized parameters to reach 'Good':
# Annual_Income: 168173.7462627645
# Delay_from_due_date: 10.985253177899002
# Num_Bank_Accounts: 0.21478779166675022
# Num_Credit_Card: 7.596425098068821
# Num_of_Loan: 1.0859338592144252
# Occupation: 0.13871523450574852
# 100%|██████████| 100/100 [00:05<00:00, 17.38trial/s, best loss: 0.0]
# Optimized parameters to reach 'Good':
# Annual_Income: 82317.5780325373
# Delay_from_due_date: 9.63250864063378
# Num_Bank_Accounts: 2.7983399440903947
# Num_Credit_Card: 1.4188387995501683
# Num_of_Delayed_Payment: 0.9847074548038091
# Num_of_Loan: 1.0859338592144252
# Occupation: 4.4092421903447185
# 100%|██████████| 100/100 [00:09<00:00, 10.63trial/s, best loss: 0.0]
# Optimized parameters to reach 'Good':
# Annual_Income: 97039.39743082748
# Changed_Credit_Limit: -5.642449626910889
# Delay_from_due_date: 20.107747128231942
# Num_Bank_Accounts: 5.381892096514039
# Num_Credit_Card: 1.4188387995501683
# Num_of_Delayed_Payment: 7.1871675790757585
# Num_of_Loan: 1.0859338592144252
# Occupation: 2.92179051747629
# 100%|██████████| 100/100 [00:05<00:00, 18.18trial/s, best loss: 0.0]
# Optimized parameters to reach 'Good':
# Annual_Income: 72340.52807771355
# Changed_Credit_Limit: -4.327532379691645
# Delay_from_due_date: -4.154381104237359
# Num_Bank_Accounts: 2.7983399440903947
# Num_Credit_Card: 1.4188387995501683
# Num_Credit_Inquiries: 5.77074623917838
# Num_of_Delayed_Payment: 0.9847074548038091
# Num_of_Loan: 3.5215938641824946
# Occupation: 3.47288485349502
# 100%|██████████| 100/100 [00:05<00:00, 16.73trial/s, best loss: 0.0]
# Optimized parameters to reach 'Good':
# Annual_Income: 29279.47686185544
# Changed_Credit_Limit: -5.793759009554918
# Credit_Mix: -9.19097308331721e-06
# Delay_from_due_date: 0.17521904681853684
# Num_Bank_Accounts: 5.381892096514039
# Num_Credit_Card: 1.4188387995501683
# Num_Credit_Inquiries: 1.9523780597595675
# Num_of_Delayed_Payment: 0.9847074548038091
# Num_of_Loan: 1.0859338592144252
# Occupation: 2.2876815290856465
# 100%|██████████| 100/100 [00:05<00:00, 18.84trial/s, best loss: 0.0]
# Optimized parameters to reach 'Good':
# Annual_Income: 37515.11983189223
# Changed_Credit_Limit: -1.9676133608066912
# Credit_Mix: -7.896702038861852e-05
# Delay_from_due_date: 15.134631576292534
# Num_Bank_Accounts: 5.381892096514039
# Num_Credit_Card: 1.4188387995501683
# Num_Credit_Inquiries: 1.9523780597595675
# Num_of_Delayed_Payment: 0.9847074548038091
# Num_of_Loan: 1.0859338592144252
# Occupation: 2.5742713753579576
# Outstanding_Debt: 889.9042599298967
# 100%|██████████| 100/100 [00:06<00:00, 14.51trial/s, best loss: 0.0]
# Optimized parameters to reach 'Good':
# Annual_Income: 111670.04959349337
# Changed_Credit_Limit: -1.5814673552015144
# Credit_Mix: -2.8843032200332984e-05
# Delay_from_due_date: 26.284288173021878
# Num_Bank_Accounts: 5.381892096514039
# Num_Credit_Card: 5.53722966522927
# Num_Credit_Inquiries: 5.77074623917838
# Num_of_Delayed_Payment: 7.1871675790757585
# Num_of_Loan: 1.0859338592144252
# Occupation: 2.7477130044619544
# Outstanding_Debt: 640.0326583318983
# Payment_of_Min_Amount: 0.7659732051746272
# 100%|██████████| 100/100 [00:05<00:00, 17.54trial/s, best loss: 0.0]
# Optimized parameters to reach 'Good':
# Annual_Income: 32729.110178533072
# Changed_Credit_Limit: -0.26961697716943256
# Credit_Mix: -7.297846873381038e-05
# Delay_from_due_date: 4.215268299454372
# Num_Bank_Accounts: 5.381892096514039
# Num_Credit_Card: 1.4188387995501683
# Num_Credit_Inquiries: 5.77074623917838
# Num_of_Delayed_Payment: 13.389627703347708
# Num_of_Loan: 1.0859338592144252
# Occupation: 1.2105384648425543
# Outstanding_Debt: 1086.6167853580923
# Payment_of_Min_Amount: 0.7659732051746272
# Total_EMI_per_month: 43820.78947675307
# 100%|██████████| 100/100 [00:06<00:00, 14.47trial/s, best loss: 0.0]
# Optimized parameters to reach 'Good':
# Amount_invested_monthly: 7509.670752069613
# Annual_Income: 118940.78944112366
# Changed_Credit_Limit: -6.079663142096514
# Credit_Mix: -3.0174605346161272e-05
# Delay_from_due_date: -1.538049242973166
# Num_Bank_Accounts: 2.7983399440903947
# Num_Credit_Card: 7.596425098068821
# Num_Credit_Inquiries: 5.77074623917838
# Num_of_Delayed_Payment: 0.9847074548038091
# Num_of_Loan: 3.5215938641824946
# Occupation: 0.4190076880555651
# Outstanding_Debt: 1130.4358031467475
# Payment_of_Min_Amount: 0.7659732051746272
# Total_EMI_per_month: 67101.00210037243
# 100%|██████████| 100/100 [00:06<00:00, 15.68trial/s, best loss: 0.0]
# Optimized parameters to reach 'Good':
# Amount_invested_monthly: 4882.902070539326
# Annual_Income: 75909.51243910051
# Changed_Credit_Limit: 0.9209044731784548
# Credit_Mix: -2.7605448748882865e-05
# Delay_from_due_date: 21.674308860943412
# Num_Bank_Accounts: 0.21478779166675022
# Num_Credit_Card: 1.4188387995501683
# Num_Credit_Inquiries: 1.9523780597595675
# Num_of_Delayed_Payment: 0.9847074548038091
# Num_of_Loan: 5.9572538691505645
# Occupation: 2.7039116280062228
# Outstanding_Debt: 37.57981083887125
# Payment_Behaviour: 4.338751698128988
# Payment_of_Min_Amount: 0.7659732051746272
# Total_EMI_per_month: 55184.52752115016
# 100%|██████████| 100/100 [00:07<00:00, 13.71trial/s, best loss: 0.0]
# Optimized parameters to reach 'Good':
# Amount_invested_monthly: 8596.35706072435
# Annual_Income: 76043.9803408559
# Changed_Credit_Limit: -2.0139293718872953
# Credit_History_Age_in_Years: 15.503671639273891
# Credit_Mix: -3.186945348888975e-05
# Delay_from_due_date: 5.920459267048191
# Num_Bank_Accounts: 7.9654442489376835
# Num_Credit_Card: 1.4188387995501683
# Num_Credit_Inquiries: 1.9523780597595675
# Num_of_Delayed_Payment: 7.1871675790757585
# Num_of_Loan: 3.5215938641824946
# Occupation: 1.5675626897477457
# Outstanding_Debt: 1189.3525024451665
# Payment_Behaviour: 3.842952453064531
# Payment_of_Min_Amount: 0.7659732051746272
# Total_EMI_per_month: 12156.289749746873

# %% [markdown]
# ### Search all feature values at once

# %%
space = {}
for feature in current_sample.index:
    if feature not in correlation_matrix["Credit_Score"] or feature == "Interest_Rate" or feature == "Age" or feature == "Occupation":
        print(f"Feature {feature} not found in correlation_matrix")
        continue
    correlation = correlation_matrix["Credit_Score"][feature]

    if feature == "Payment_of_Min_Amount":
        space[feature] = hp.choice(feature, [0, 1])
    # elif "Num_" in feature:
    #     if correlation > 0:
    #         space[feature] = hp.quniform(feature, current_sample[feature], max(max_values[feature], current_sample[feature] + epsilon), 1)
    #     else:
    #         space[feature] = hp.quniform(feature, min(min_values[feature], current_sample[feature] - epsilon), current_sample[feature], 1)
    else:
        if correlation > 0:
            space[feature] = hp.uniform(feature, current_sample[feature], max(max_values[feature], current_sample[feature] + epsilon))
        else:
            space[feature] = hp.uniform(feature, min(min_values[feature], current_sample[feature] - epsilon), current_sample[feature])

trials = Trials()
best_params = fmin(
    fn=objective,
    space=space,
    algo=tpe.suggest,
    max_evals=500,
    trials=trials
)
print(f"Optimized parameters to reach 'Good': ")
for feature_name, scaled_values in best_params.items():
      mean = sc.mean_[X.columns.get_loc(feature_name)]
      scale = sc.scale_[X.columns.get_loc(feature_name)]

      original_values = scaled_values * scale + mean
      print(f"{feature_name}: {original_values}")
# Out:
# Feature Age not found in correlation_matrix
# 100%|██████████| 500/500 [00:42<00:00, 11.81trial/s, best loss: 0.0]
# Optimized parameters to reach 'Good': Amount_invested_monthly: 9241.708422157473
# Optimized parameters to reach 'Good': Annual_Income: 27438.694734284923
# Optimized parameters to reach 'Good': Changed_Credit_Limit: -1.687446912347962
# Optimized parameters to reach 'Good': Credit_History_Age_in_Years: 16.441839346342242
# Optimized parameters to reach 'Good': Credit_Mix: -8.487915555060755e-05
# Optimized parameters to reach 'Good': Delay_from_due_date: 28.13846737130961
# Optimized parameters to reach 'Good': Num_Bank_Accounts: 1.1390788686262816
# Optimized parameters to reach 'Good': Num_Credit_Card: 2.164272539947442
# Optimized parameters to reach 'Good': Num_Credit_Inquiries: 5.487237983630703
# Optimized parameters to reach 'Good': Num_of_Delayed_Payment: 10.484781797004567
# Optimized parameters to reach 'Good': Num_of_Loan: 4.4844174330563025
# Optimized parameters to reach 'Good': Occupation: 3.4729889912739385
# Optimized parameters to reach 'Good': Outstanding_Debt: 225.97883335240817
# Optimized parameters to reach 'Good': Payment_Behaviour: 2.8752263702943925
# Optimized parameters to reach 'Good': Payment_of_Min_Amount: 0.7659732051746272
# Optimized parameters to reach 'Good': Total_EMI_per_month: 58530.29612549646
